# %% [markdown]
# <a href="https://colab.research.google.com/github/Samrat-Abdul-Jalil/Daily-task/blob/main/Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df=pd.read_excel("/content/drive/MyDrive/task/Task.xlsx")

# %%
df.head()
# Out:
#    task_name  Due date        type  marks  options  weight  time to finish
# 0     os lab       2.0          ct   20.0      0.0     4.0             2.5
# 1  os theory       5.0          ct   20.0      0.0     4.0             2.5
# 2        Hci       2.0     project    0.0      1.0     1.0             1.0
# 3  Economics       3.0  assignment    5.0      0.0     3.0             5.0
# 4  Economics       3.0          ct   20.0      1.0     2.0             5.0

# %%
t=(df["Due date"]*-2)+(df['marks'])+(df['options']*-2)+(df['weight']*1.3)
result=t.sort_values(ascending=False)

# %%
df.insert(0,"result",t)

# %%
df.head()
df.sort_values(by=['result'],ascending=False)
# Out:
#    result  task_name  Due date        type  marks  options  weight  \
# 0    21.2     os lab       2.0          ct   20.0      0.0     4.0
# 5    19.9     os lab       2.0  assignment   20.0      0.0     3.0
# 6    16.5         Bi       5.0          ct   20.0      0.0     5.0
# 1    15.2  os theory       5.0          ct   20.0      0.0     4.0
# 4    14.6  Economics       3.0          ct   20.0      1.0     2.0
# 3     2.9  Economics       3.0  assignment    5.0      0.0     3.0
# 2    -4.7        Hci       2.0     project    0.0      1.0     1.0
#
#    time to finish
# 0             2.5
# 5             5.0
# 6             6.0
# 1             2.5
# 4             5.0
# 3             5.0
# 2             1.0

# %%
df.head()
df.sort_values(by=['Due date'],ascending=True)
# Out:
#    result  task_name  Due date        type  marks  options  weight  \
# 0    21.2     os lab       2.0          ct   20.0      0.0     4.0
# 2    -4.7        Hci       2.0     project    0.0      1.0     1.0
# 5    19.9     os lab       2.0  assignment   20.0      0.0     3.0
# 3     2.9  Economics       3.0  assignment    5.0      0.0     3.0
# 4    14.6  Economics       3.0          ct   20.0      1.0     2.0
# 1    15.2  os theory       5.0          ct   20.0      0.0     4.0
# 6    16.5         Bi       5.0          ct   20.0      0.0     5.0
#
#    time to finish
# 0             2.5
# 2             1.0
# 5             5.0
# 3             5.0
# 4             5.0
# 1             2.5
# 6             6.0

# %%
df.sort_values(by=['time to finish'],ascending=True)
# Out:
#    result  task_name  Due date        type  marks  options  weight  \
# 2    -4.7        Hci       2.0     project    0.0      1.0     1.0
# 0    21.2     os lab       2.0          ct   20.0      0.0     4.0
# 1    15.2  os theory       5.0          ct   20.0      0.0     4.0
# 3     2.9  Economics       3.0  assignment    5.0      0.0     3.0
# 4    14.6  Economics       3.0          ct   20.0      1.0     2.0
# 5    19.9     os lab       2.0  assignment   20.0      0.0     3.0
# 6    16.5         Bi       5.0          ct   20.0      0.0     5.0
#
#    time to finish
# 2             1.0
# 0             2.5
# 1             2.5
# 3             5.0
# 4             5.0
# 5             5.0
# 6             6.0
